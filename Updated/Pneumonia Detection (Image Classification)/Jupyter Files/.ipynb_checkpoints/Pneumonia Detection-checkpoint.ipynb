# %% [markdown]
# ## LIBRARIES

# %%
import math
import numpy as np
from PIL import Image
import pandas as pd

# File things
import os

# CROSS VALIDATION
from sklearn.model_selection import cross_val_score, cross_val_predict, cross_validate

#TEST RESULT
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#PREPROCESSING (Normalize)
from sklearn.preprocessing import MinMaxScaler

#SCATTER PLOT
import matplotlib.pyplot as plt
import seaborn as sns

# Image Embedding
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.models import Model

# LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression

# SVM
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

#NAIVE BAYES
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## IMAGE EMBEDDING

# %%
# PRERPOCESS IMAGE
def preprocess_image(image_path):
    img = Image.open(image_path).convert("RGB")   # TURN IMAGE TO 3 CHANNELS (*input channel needed for InceptionV3)
    img = img.resize((299, 299))                  # RESIZE IMAGE (*size needed for InceptionV3)
    img_array = np.array(img)                     # TURN TO 3D ARRAY (299, 299, 3)
    img_array = np.expand_dims(img_array, axis=0) # TURN TO 4D ARRAY (1, 299, 299, 3) [1, batchSize]
    img_array = preprocess_input(img_array)       # APPLY Inception V3 PREPROCESSING
    return img_array  # 4D ARRAY

# USE THE MODEL TO MAKE VECTOR REPRESENTATION OF THE IMAGE
def generate_embedding(image_path):
    img_array = preprocess_image(image_path)      # 4D ARRAY (batch_size, SX, SY, colorChannels)
    embedding = model.predict(img_array)
    return embedding.flatten()                    # TURN NEW FEATURES TO 1D ARRAY

# GENERATE EMBEDDING FOR EVERY SUBFOLDER (category = subFolderName) AND OUTPUT A CSV (*containing new features) (LIKE ORANGE)
def process_folder(folder_path, output_csv):
    embeddings = []  # NEW FEATURES ADDED BY THE MODEL
    image_names = [] # IMAGE NAMES
    categories = []  # CATEGORY NAME BASED ON FOLDER NAME
    
    for subdir, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif')):
                image_path = os.path.join(subdir, filename)
                category = os.path.basename(subdir)
                print(f"Processing: {filename} from category: {category}")
                
                embedding = generate_embedding(image_path) # GENERATE EMBEDDING

                # PUT TO DESIGNATED ARRAYS
                embeddings.append(embedding)
                image_names.append(filename)
                categories.append(category)  
    
    # CREATE TABLE (DataFrame) AND INSERT NEW COLUMNS
    df = pd.DataFrame(embeddings)
    df.insert(0, "Category", categories)     # ADD CATEGORY TO 1ST COLUMN
    df.insert(1, "Image Name", image_names)  # ADD IMAGE NAME TO 2ND COLUMN
    
    # DataFrame TO CSV
    df.to_csv(output_csv, index=False)
    print(f"Embeddings saved to {output_csv}")

# %%
#*******************************************BASE IMAGE EMBEDDING*******************************************
#LOAD THE EMBEDDER MODEL (InceptionV3) *default pretrained weights (imagenet)
base_model = InceptionV3(weights='imagenet', include_top=True)

#CREATE NEW MODEL THAT OUTPUTS VECTOR REPRESENTATION OF THE IMAGE
model = Model(inputs=base_model.input, outputs=base_model.get_layer('avg_pool').output)
#*******************************************BASE IMAGE EMBEDDING*******************************************




# INCLUDE BOTH NORMAL AND PNEUMONIA
#*******************************************TRAIN IMAGE EMBEDDING*******************************************
print("TRAIN EMBEDDING")
#TRAIN FOLDER LOCATION
Train_FileLoc = r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Datasets\FIXED DATASETS\TRAIN"  # Replace with your folder path

#FILE LOCATION FOR THE CSV FILE (w added features)
TRAIN_CSV_Folder = ".CSV FILE (ADDED FEATURES)"                                       
TRAIN_CSV_FileLoc = os.path.join(TRAIN_CSV_Folder, "image_embeddings_TRAIN.csv") #FILENAME

#RETURNS .CSV FILE
process_folder(Train_FileLoc, TRAIN_CSV_FileLoc)
#*******************************************TRAIN IMAGE EMBEDDING*******************************************





# INCLUDE BOTH NORMAL AND PNEUMONIA
#*******************************************TEST IMAGE EMBEDDING*******************************************
print("TEST EMBEDDING")
#TEST FOLDER LOCATION
Test_FileLoc = r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Datasets\FIXED DATASETS\TEST"  # Replace with your folder path

#FILE LOCATION FOR THE CSV FILE (w added features)
TEST_CSV_Folder = ".CSV FILE (ADDED FEATURES)"                                       
TEST_CSV_FileLoc = os.path.join(TEST_CSV_Folder, "image_embeddings_TEST.csv") #FILENAME

#RETURNS .CSV FILE
process_folder(Test_FileLoc, TEST_CSV_FileLoc)
#*******************************************TEST IMAGE EMBEDDING*******************************************
# Out:
# TRAIN EMBEDDING
# Processing: IM-0145-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 4s 4s/step
# Processing: IM-0147-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 126ms/step
# Processing: IM-0149-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 105ms/step
# Processing: IM-0151-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 92ms/step
# Processing: IM-0152-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 102ms/step
# Processing: IM-0154-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 106ms/step
# Processing: IM-0156-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 90ms/step
# Processing: IM-0158-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 99ms/step
# Processing: IM-0160-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 100ms/step
# Processing: IM-0162-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 92ms/step
# Processing: IM-0164-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 109ms/step
# Processing: IM-0166-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 113ms/step
# Processing: IM-0168-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 94ms/step
# Processing: IM-0170-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 92ms/step
# Processing: IM-0172-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0176-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 102ms/step
# Processing: IM-0177-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0178-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0180-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 103ms/step
# Processing: IM-0182-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 127ms/step
# Processing: IM-0183-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 122ms/step
# Processing: IM-0185-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 146ms/step
# Processing: IM-0187-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 138ms/step
# Processing: IM-0189-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 141ms/step
# Processing: IM-0191-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 130ms/step
# Processing: IM-0193-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 117ms/step
# Processing: IM-0195-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 130ms/step
# Processing: IM-0199-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 109ms/step
# Processing: IM-0201-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 115ms/step
# Processing: IM-0203-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 167ms/step
# Processing: IM-0205-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0206-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 90ms/step
# Processing: IM-0207-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0209-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0210-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0211-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0213-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0214-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0215-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0216-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0217-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0218-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0219-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0220-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0221-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0222-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 84ms/step
# Processing: IM-0223-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 90ms/step
# Processing: IM-0224-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0225-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0226-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0227-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0228-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0229-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0230-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0231-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0234-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0235-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0236-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 102ms/step
# Processing: IM-0237-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0238-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0239-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0240-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0241-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0242-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0243-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0244-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0245-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0248-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0249-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0250-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0251-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0253-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 90ms/step
# Processing: IM-0255-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0256-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0257-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0261-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0262-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0264-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0265-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0266-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0268-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0269-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0270-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0272-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0273-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0274-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0275-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0276-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0277-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0278-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0279-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0280-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 94ms/step
# Processing: IM-0282-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0283-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0285-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0286-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0288-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0289-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0290-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0291-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0292-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0293-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0294-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0295-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 101ms/step
# Processing: IM-0297-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0298-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 95ms/step
# Processing: IM-0299-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0300-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 84ms/step
# Processing: IM-0301-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0302-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0303-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 115ms/step
# Processing: IM-0304-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0305-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0306-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 115ms/step
# Processing: IM-0307-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 121ms/step
# Processing: IM-0308-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 119ms/step
# Processing: IM-0309-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 115ms/step
# Processing: IM-0311-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 112ms/step
# Processing: IM-0312-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 112ms/step
# Processing: IM-0313-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 120ms/step
# Processing: IM-0314-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0315-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0316-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0317-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0318-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0319-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 100ms/step
# Processing: IM-0320-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0323-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0324-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0325-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0326-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0327-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0329-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0330-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0331-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0332-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0333-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0335-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0337-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0338-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0339-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 84ms/step
# Processing: IM-0340-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0341-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0343-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0345-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: person10_bacteria_43.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person11_bacteria_45.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 92ms/step
# Processing: person12_bacteria_46.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person12_bacteria_47.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person12_bacteria_48.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person13_bacteria_49.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person13_bacteria_50.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person14_bacteria_51.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person15_bacteria_52.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person16_bacteria_53.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person16_bacteria_54.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 84ms/step
# Processing: person16_bacteria_55.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 134ms/step
# Processing: person17_bacteria_56.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 134ms/step
# Processing: person18_bacteria_57.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 139ms/step
# Processing: person19_bacteria_58.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 144ms/step
# Processing: person19_bacteria_59.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 127ms/step
# Processing: person19_bacteria_60.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person19_bacteria_61.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 116ms/step
# Processing: person19_bacteria_62.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person19_bacteria_63.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person20_bacteria_64.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person20_bacteria_66.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person20_bacteria_67.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 109ms/step
# Processing: person20_bacteria_69.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person20_bacteria_70.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 118ms/step
# Processing: person21_bacteria_72.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person21_bacteria_73.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 131ms/step
# Processing: person22_bacteria_74.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person22_bacteria_76.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person22_bacteria_77.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person23_bacteria_100.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person23_bacteria_101.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person23_bacteria_102.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 114ms/step
# Processing: person23_bacteria_103.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 119ms/step
# Processing: person23_bacteria_104.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 128ms/step
# Processing: person23_bacteria_105.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person23_bacteria_106.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person23_bacteria_107.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person23_bacteria_78.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person23_bacteria_79.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person23_bacteria_80.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person23_bacteria_81.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person23_bacteria_82.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person23_bacteria_83.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 119ms/step
# Processing: person23_bacteria_84.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 108ms/step
# Processing: person23_bacteria_85.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person23_bacteria_86.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 122ms/step
# Processing: person23_bacteria_87.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person23_bacteria_88.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person23_bacteria_89.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person23_bacteria_90.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person23_bacteria_91.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person23_bacteria_92.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 108ms/step
# Processing: person23_bacteria_93.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person23_bacteria_94.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 140ms/step
# Processing: person23_bacteria_95.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 138ms/step
# Processing: person23_bacteria_96.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 136ms/step
# Processing: person23_bacteria_97.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 134ms/step
# Processing: person23_bacteria_98.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 138ms/step
# Processing: person23_bacteria_99.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 148ms/step
# Processing: person24_bacteria_108.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 139ms/step
# Processing: person24_bacteria_109.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 137ms/step
# Processing: person24_bacteria_110.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 136ms/step
# Processing: person24_bacteria_111.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 144ms/step
# Processing: person24_bacteria_112.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 162ms/step
# Processing: person25_bacteria_113.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 109ms/step
# Processing: person25_bacteria_114.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person25_bacteria_115.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person25_bacteria_116.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person25_bacteria_117.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person25_bacteria_118.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person25_bacteria_119.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 118ms/step
# Processing: person25_bacteria_120.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 135ms/step
# Processing: person25_bacteria_121.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person26_bacteria_122.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person26_bacteria_123.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 114ms/step
# Processing: person26_bacteria_124.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person26_bacteria_126.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 108ms/step
# Processing: person26_bacteria_127.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 128ms/step
# Processing: person26_bacteria_128.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person26_bacteria_129.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person26_bacteria_130.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person26_bacteria_131.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person26_bacteria_132.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person26_bacteria_133.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person27_bacteria_135.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person27_bacteria_136.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person27_bacteria_137.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person27_bacteria_138.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 119ms/step
# Processing: person28_bacteria_139.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person28_bacteria_141.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 116ms/step
# Processing: person28_bacteria_142.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person28_bacteria_143.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person29_bacteria_144.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person30_bacteria_145.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person30_bacteria_146.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person30_bacteria_147.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person30_bacteria_148.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person30_bacteria_149.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 121ms/step
# Processing: person30_bacteria_150.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person30_bacteria_151.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person30_bacteria_152.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person30_bacteria_153.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person30_bacteria_154.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person30_bacteria_155.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person30_bacteria_156.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person30_bacteria_157.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person30_bacteria_158.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person31_bacteria_160.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 108ms/step
# Processing: person31_bacteria_161.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person31_bacteria_162.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 130ms/step
# Processing: person31_bacteria_163.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 117ms/step
# Processing: person31_bacteria_164.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person32_bacteria_165.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person32_bacteria_166.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 115ms/step
# Processing: person33_bacteria_169.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person33_bacteria_172.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person33_bacteria_173.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person33_bacteria_174.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 125ms/step
# Processing: person33_bacteria_175.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person34_bacteria_176.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person35_bacteria_178.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person35_bacteria_180.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person35_bacteria_181.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person36_bacteria_182.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person36_bacteria_183.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person36_bacteria_184.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person36_bacteria_185.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person37_bacteria_186.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person37_bacteria_187.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person37_bacteria_188.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person37_bacteria_189.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 120ms/step
# Processing: person38_bacteria_190.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person38_bacteria_191.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person38_bacteria_192.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person38_bacteria_193.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 116ms/step
# Processing: person38_bacteria_194.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person7_bacteria_25.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 135ms/step
# Processing: person7_bacteria_28.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person7_bacteria_29.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person8_bacteria_37.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 111ms/step
# Processing: person9_bacteria_38.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person9_bacteria_39.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 144ms/step
# Processing: person9_bacteria_40.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 143ms/step
# Processing: person9_bacteria_41.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 160ms/step
# Embeddings saved to .CSV FILE (ADDED FEATURES)\image_embeddings_TRAIN.csv
# TEST EMBEDDING
# Processing: IM-0001-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 143ms/step
# Processing: IM-0003-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 142ms/step
# Processing: IM-0005-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0006-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 113ms/step
# Processing: IM-0007-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 119ms/step
# Processing: IM-0009-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 138ms/step
# Processing: IM-0010-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 118ms/step
# Processing: IM-0011-0001-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0011-0001-0002.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 119ms/step
# Processing: IM-0011-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 121ms/step
# Processing: IM-0013-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 112ms/step
# Processing: IM-0015-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0016-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0017-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0019-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0021-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0022-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0023-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 112ms/step
# Processing: IM-0025-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 121ms/step
# Processing: IM-0027-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0028-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 112ms/step
# Processing: IM-0029-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 116ms/step
# Processing: IM-0030-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0031-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 111ms/step
# Processing: IM-0033-0001-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0033-0001-0002.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 121ms/step
# Processing: IM-0033-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 110ms/step
# Processing: IM-0035-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 116ms/step
# Processing: IM-0036-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0037-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: IM-0039-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0041-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0043-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 84ms/step
# Processing: IM-0045-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 100ms/step
# Processing: IM-0046-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0049-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 104ms/step
# Processing: IM-0050-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0059-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0061-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0063-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0065-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0067-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: IM-0069-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0070-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0071-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0073-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0075-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0077-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 93ms/step
# Processing: IM-0079-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 90ms/step
# Processing: IM-0081-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0083-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 91ms/step
# Processing: IM-0084-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0085-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0086-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 98ms/step
# Processing: IM-0087-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 85ms/step
# Processing: IM-0089-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0091-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0093-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0095-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0097-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: IM-0099-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0101-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 101ms/step
# Processing: IM-0102-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0103-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0105-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0107-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: IM-0109-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0110-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: IM-0111-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 89ms/step
# Processing: NORMAL2-IM-0007-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 86ms/step
# Processing: NORMAL2-IM-0012-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: NORMAL2-IM-0013-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: NORMAL2-IM-0019-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 88ms/step
# Processing: NORMAL2-IM-0023-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: NORMAL2-IM-0027-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 87ms/step
# Processing: NORMAL2-IM-0028-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 124ms/step
# Processing: NORMAL2-IM-0029-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 114ms/step
# Processing: NORMAL2-IM-0030-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 116ms/step
# Processing: NORMAL2-IM-0033-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 119ms/step
# Processing: NORMAL2-IM-0035-0001.jpeg from category: NORMAL
# 1/1 [==============================] - 0s 120ms/step
# Processing: person10_virus_35.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 159ms/step
# Processing: person11_virus_38.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person14_virus_44.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 113ms/step
# Processing: person15_virus_46.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 110ms/step
# Processing: person16_virus_47.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 103ms/step
# Processing: person17_virus_48.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person18_virus_49.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person19_virus_50.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person1_virus_11.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 92ms/step
# Processing: person1_virus_12.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 96ms/step
# Processing: person1_virus_13.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person1_virus_6.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 112ms/step
# Processing: person1_virus_7.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person1_virus_8.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person1_virus_9.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person20_virus_51.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person21_virus_52.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 85ms/step
# Processing: person21_virus_53.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person22_virus_54.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person22_virus_55.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person23_virus_56.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person24_virus_58.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person25_virus_59.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 98ms/step
# Processing: person26_virus_60.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 94ms/step
# Processing: person28_virus_62.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 94ms/step
# Processing: person28_virus_63.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 85ms/step
# Processing: person29_virus_64.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person30_virus_69.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 96ms/step
# Processing: person31_virus_70.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person32_virus_71.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person33_virus_72.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 102ms/step
# Processing: person34_virus_76.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person35_virus_80.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person36_virus_81.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person37_virus_82.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person38_virus_83.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 93ms/step
# Processing: person38_virus_84.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 108ms/step
# Processing: person39_virus_85.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person3_virus_15.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 91ms/step
# Processing: person3_virus_16.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person3_virus_17.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person40_virus_87.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person41_virus_88.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person42_virus_89.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person43_virus_92.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person44_virus_93.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person44_virus_94.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person45_virus_95.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person46_virus_96.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person47_virus_99.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 97ms/step
# Processing: person48_virus_100.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person49_virus_101.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person50_virus_102.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person51_virus_105.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person52_virus_106.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person53_virus_107.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person53_virus_108.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person54_virus_109.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person55_virus_110.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 93ms/step
# Processing: person56_virus_112.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person57_virus_113.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person59_virus_116.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person60_virus_117.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 96ms/step
# Processing: person61_virus_118.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person62_virus_119.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person63_virus_121.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 103ms/step
# Processing: person64_virus_122.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 91ms/step
# Processing: person65_virus_123.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person66_virus_125.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person67_virus_126.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 89ms/step
# Processing: person69_virus_129.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 90ms/step
# Processing: person70_virus_130.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 92ms/step
# Processing: person71_virus_131.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 87ms/step
# Processing: person71_virus_132.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 92ms/step
# Processing: person72_virus_133.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 126ms/step
# Processing: person74_virus_135.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 86ms/step
# Processing: person75_virus_136.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 92ms/step
# Processing: person76_virus_138.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person8_virus_27.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 88ms/step
# Processing: person8_virus_28.jpeg from category: PNEUMONIA
# 1/1 [==============================] - 0s 93ms/step
# Embeddings saved to .CSV FILE (ADDED FEATURES)\image_embeddings_TEST.csv

# %% [markdown]
# ## IMAGE EMBEDDED FILE AND PREPROCESSING

# %%
#WHOLE FILE = df
#******************************************FILE TRAIN******************************************
# FILE SETUP
# FILE LOCATION
df1_train = pd.read_csv(r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Jupyter Files\.CSV FILE (ADDED FEATURES)\image_embeddings_TRAIN.csv")

# SHOW COLUMN TYPES AND DETAILS
print(df1_train.info())  
#******************************************FILE TRAIN******************************************





#******************************************FILE TEST******************************************
# FILE SETUP
# FILE LOCATION
df2_test = pd.read_csv(r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Jupyter Files\.CSV FILE (ADDED FEATURES)\image_embeddings_TEST.csv")

# SHOW COLUMN TYPES AND DETAILS
print(df2_test.info())  
#******************************************FILE TEST******************************************
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Columns: 2050 entries, Category to 2047
# dtypes: float64(2048), object(2)
# memory usage: 4.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Columns: 2050 entries, Category to 2047
# dtypes: float64(2048), object(2)
# memory usage: 2.5+ MB
# None

# %%
#******************************************GET TRAIN AND TEST DATA ROLES******************************************
Train_X = df1_train.drop(columns=['Category', 'Image Name'])   # FEATURES (EXCEPT EngagementLevel)
Train_Y = df1_train['Category']                                # TARGET

Test_X = df2_test.drop(columns=['Category', 'Image Name'])     # FEATURES (EXCEPT EngagementLevel)
Test_Y = df2_test['Category']                                  # TARGET
#******************************************GET TRAIN AND TEST DATA ROLES******************************************





#******************************************NORMALIZE VALUES******************************************#
scaler = MinMaxScaler()

Train_X_normalized = scaler.fit_transform(Train_X)
Test_X_normalized = scaler.fit_transform(Test_X)

scaler = StandardScaler()

Train_X_stamdarized = scaler.fit_transform(Train_X)
Test_X_stamdarized = scaler.fit_transform(Test_X)
#******************************************NORMALIZE VALUES******************************************#

# %%
#******************************************IMAGE VIEWER SETUP******************************************#
normal_folder = r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Datasets\FIXED DATASETS\TRAIN\NORMAL"
pneumonia_folder = r"G:\MIKE\Programming\2024\Repositories\Atillo-ML\Updated\Pneumonia Detection (Image Classification)\Datasets\FIXED DATASETS\TRAIN\PNEUMONIA"

# ALL IMAGE FILE PATH AND LABELS
image_paths = []
labels = []
normal_count = 0
pneumonia_count = 0

# NORMAL images
for img_file in os.listdir(normal_folder):
    image_paths.append(os.path.join(normal_folder, img_file))
    labels.append("NORMAL")
    normal_count += 1

# PNEUMONIA images
for img_file in os.listdir(pneumonia_folder):
    image_paths.append(os.path.join(pneumonia_folder, img_file))
    labels.append("PNEUMONIA")
    pneumonia_count += 1

# TURN TO NUMPY ARRAY
true_labels = np.array(labels)
image_paths = np.array(image_paths)


print("true_labels", len(true_labels))
print("Normal count    : ", normal_count)
print("Pneumonia count : ", pneumonia_count)
#******************************************IMAGE VIEWER SETUP******************************************#
# Out:
# true_labels 290
# Normal count    :  145
# Pneumonia count :  145

# %% [markdown]
# # ------------------------------LOGISTIC REGRESSION------------------------------

# %%
#USING X_train AND y_train in TREE MODEL
#******************************************LOGISTIC REGRESSION******************************************
log_reg = LogisticRegression( 
    penalty      = 'l2',
    C            = 1,
    random_state = 0,
    max_iter     = 100,
    solver='lbfgs'                # Multi-Class Logistic Regression solver
)

log_reg.fit(Train_X_normalized, Train_Y)
#******************************************LOGISTIC REGRESSION******************************************




#UNUSED
#******************************************LOGISTIC REGRESSION PREDICTION******************************************
#y_pred_Log_Reg = log_reg.predict(Test_X_normalized)
#******************************************LOGISTIC REGRESSION PREDICTION******************************************





#******************************************CROSS VALIDATION METRIC******************************************
#CROSS VALIDATION SCORE
accuracy_results  = cross_validate(log_reg, Train_X_normalized, Train_Y, cv=10, scoring='accuracy')
accuracy_scores = accuracy_results['test_score']
mean_accuracy = np.mean(accuracy_scores) * 100

f1_results = cross_validate(log_reg, Train_X_normalized, Train_Y, cv=10, scoring='f1_weighted')
f1_scores = f1_results['test_score']
mean_f1 = np.mean(f1_scores) * 100

recall_results = cross_validate(log_reg, Train_X_normalized, Train_Y, cv=10, scoring='recall_weighted')
recall_scores = recall_results['test_score']
mean_recall = np.mean(recall_scores) * 100

precision_results = cross_validate(log_reg, Train_X_normalized, Train_Y, cv=10, scoring='precision_weighted')
precision_scores = precision_results['test_score']
mean_precision = np.mean(precision_scores) * 100

#DRAW VALIDATION SCORE
print(f"10 Cross-Validation Results:")
print(f"Accuracy Score  : {mean_accuracy:.2f}%")
print(f"F1 Score        : {mean_f1:.2f}%")
print(f"Recall Score    : {mean_recall:.2f}%")
print(f"Precision Score : {mean_precision:.2f}% \n")
#******************************************CROSS VALIDATION METRIC******************************************





#******************************************CROSS VALIDATION CM******************************************
# Get predictions from cross-validation
y_pred_cv_log_reg = cross_val_predict(log_reg, Train_X_normalized, Train_Y, cv=10)

cm = confusion_matrix(Train_Y, y_pred_cv_log_reg)

labels = ["Normal", "Pneumonia"]

plt.figure(figsize=(4, 4))  # WIDTH HEIGHT
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix - Logisitic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.xticks(rotation=90, fontsize=10)  
plt.yticks(rotation=0, fontsize=10)   

plt.tight_layout()

plt.show()
#******************************************CROSS VALIDATION CM******************************************





#******************************************IMAGE VIEWER******************************************
# Misclassified Indices Using Cross-Validation Predictions
misclassified_indices_cv = [i for i, (true, pred) in enumerate(zip(true_labels, y_pred_cv_log_reg)) if true != pred]

print("Number of Misclassified Images: ",len(misclassified_indices_cv))

# Display up to 17 misclassified images (or less, if fewer misclassified images)
num_images = min(100, len(misclassified_indices_cv))  # Display up to 17 misclassified images

# Calculate rows and columns for a square grid
grid_size = math.ceil(math.sqrt(num_images))  # Grid size for square layout

plt.figure(figsize=(10, 10))  # Adjust figure size

for idx, mis_idx in enumerate(misclassified_indices_cv[:num_images]):
    # Load image
    img_path = image_paths[mis_idx]
    img = plt.imread(img_path)  # Read the image
    
    # Get true and predicted labels
    true_label = true_labels[mis_idx]
    predicted_label = y_pred_cv_log_reg[mis_idx]

    # Plot the image
    plt.subplot(grid_size, grid_size, idx + 1)
    plt.imshow(img, cmap='gray')  # Adjust 'gray' if images are in grayscale
    plt.title(f"True: {true_label}\nPred: {predicted_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
#******************************************IMAGE VIEWER******************************************
# Out:
# 10 Cross-Validation Results:
# Accuracy Score  : 94.14%
# F1 Score        : 94.12%
# Recall Score    : 94.83%
# Precision Score : 94.47%
# Number of Misclassified Images:  17

# %% [markdown]
# # ------------------------------SVM------------------------------

# %%
#******************************************SVM******************************************
svm_classifier = SVC(
    kernel='rbf',   # KERNEL
    C=1,            # COST PARAMETER RELATED TO COMPLEXITY BOUND
    gamma='auto',   # G
    tol=0.001,      # NUMERICAL TOLERANCE
    max_iter=400    # ITERATION LIMIT
)

svm_classifier.fit(Train_X_stamdarized, Train_Y)
#******************************************SVM******************************************




#UNUSED
#******************************************SVM PREDICTION******************************************
#y_pred_SVM = svm_classifier.predict(X_test_scaled)
#******************************************SVM PREDICTION******************************************




#******************************************CROSS VALIDATION METRICS******************************************
#CROSS VALIDATION SCORE
accuracy_results  = cross_validate(svm_classifier, Train_X_stamdarized, Train_Y, cv=10, scoring='accuracy')
accuracy_scores = accuracy_results['test_score']
mean_accuracy = np.mean(accuracy_scores) * 100

f1_results = cross_validate(svm_classifier, Train_X_stamdarized, Train_Y, cv=10, scoring='f1_weighted')
f1_scores = f1_results['test_score']
mean_f1 = np.mean(f1_scores) * 100

recall_results = cross_validate(svm_classifier, Train_X_stamdarized, Train_Y, cv=10, scoring='recall_weighted')
recall_scores = recall_results['test_score']
mean_recall = np.mean(recall_scores) * 100

precision_results = cross_validate(svm_classifier, Train_X_stamdarized, Train_Y, cv=10, scoring='precision_weighted')
precision_scores = precision_results['test_score']
mean_precision = np.mean(precision_scores) * 100

#DRAW VALIDATION SCORE
print(f"10 Cross-Validation Results:")
print(f"Accuracy Score  : {mean_accuracy:.2f}%")
print(f"F1 Score        : {mean_f1:.2f}%")
print(f"Recall Score    : {mean_recall:.2f}%")
print(f"Precision Score : {mean_precision:.2f}% \n")
#******************************************CROSS VALIDATION METRICS******************************************




#******************************************CROSS VALIDATION CM******************************************
# Get predictions from cross-validation
y_pred_cv_svm = cross_val_predict(svm_classifier, Train_X_stamdarized, Train_Y, cv=10)

cm = confusion_matrix(Train_Y, y_pred_cv_svm)

labels = ["Normal", "Pneumonia"]

plt.figure(figsize=(4, 4))  # WIDTH HEIGHT
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix - Support Vector Machine')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.xticks(rotation=90, fontsize=10)  
plt.yticks(rotation=0, fontsize=10)   

plt.tight_layout()

plt.show()
#******************************************CROSS VALIDATION CM******************************************




#******************************************IMAGE VIEWER******************************************
# Misclassified Indices Using Cross-Validation Predictions
misclassified_indices_cv = [i for i, (true, pred) in enumerate(zip(true_labels, y_pred_cv_svm)) if true != pred]

print("Number of Misclassified Images: ",len(misclassified_indices_cv))

# Display up to 17 misclassified images (or less, if fewer misclassified images)
num_images = min(100, len(misclassified_indices_cv))  # Display up to 17 misclassified images

# Calculate rows and columns for a square grid
grid_size = math.ceil(math.sqrt(num_images))  # Grid size for square layout

plt.figure(figsize=(10, 10))  # Adjust figure size

for idx, mis_idx in enumerate(misclassified_indices_cv[:num_images]):
    # Load image
    img_path = image_paths[mis_idx]
    img = plt.imread(img_path)  # Read the image
    
    # Get true and predicted labels
    true_label = true_labels[mis_idx]
    predicted_label = y_pred_cv_svm[mis_idx]

    # Modify true_label based on the conditions
    if true_label == "PNEUMONIA":
        true_label = "Pneumonia"
    elif true_label == "NORMAL":
        true_label = "Normal"
    
    # Modify predicted_label based on the conditions
    if predicted_label == "PNEUMONIA":
        predicted_label = "Pneumonia"
    elif predicted_label == "NORMAL":
        predicted_label = "Normal"

    # Plot the image
    plt.subplot(grid_size, grid_size, idx + 1)
    #plt.subplot(1, 5, idx + 1)
    plt.imshow(img, cmap='gray')  # Adjust 'gray' if images are in grayscale
    plt.title(f"True: {true_label}\nPred: {predicted_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
#******************************************IMAGE VIEWER******************************************
# Out:
# 10 Cross-Validation Results:
# Accuracy Score  : 94.83%
# F1 Score        : 94.80%
# Recall Score    : 94.83%
# Precision Score : 95.28%
# Number of Misclassified Images:  15

# %% [markdown]
# # ------------------------------NAIVE BAYES------------------------------

# %%
#******************************************GAUSSIAN NAIVE BAYES******************************************
naiveBayes_classifier = GaussianNB()

naiveBayes_classifier.fit(Train_X_normalized, Train_Y)
#******************************************GAUSSIAN NAIVE BAYES******************************************




#******************************************CROSS VALIDATION METRIC******************************************
#CROSS VALIDATION SCORE
accuracy_results  = cross_validate(naiveBayes_classifier, Train_X_normalized, Train_Y, cv=10, scoring='accuracy')
accuracy_scores = accuracy_results['test_score']
mean_accuracy = np.mean(accuracy_scores) * 100

f1_results = cross_validate(naiveBayes_classifier, Train_X_normalized, Train_Y, cv=10, scoring='f1_weighted')
f1_scores = f1_results['test_score']
mean_f1 = np.mean(f1_scores) * 100

recall_results = cross_validate(naiveBayes_classifier, Train_X_normalized, Train_Y, cv=10, scoring='recall_weighted')
recall_scores = recall_results['test_score']
mean_recall = np.mean(recall_scores) * 100

precision_results = cross_validate(naiveBayes_classifier, Train_X_normalized, Train_Y, cv=10, scoring='precision_weighted')
precision_scores = precision_results['test_score']
mean_precision = np.mean(precision_scores) * 100

#DRAW VALIDATION SCORE
print(f"10 Cross-Validation Results:")
print(f"Accuracy Score  : {mean_accuracy:.2f}%")
print(f"F1 Score        : {mean_f1:.2f}%")
print(f"Recall Score    : {mean_recall:.2f}%")
print(f"Precision Score : {mean_precision:.2f}% \n")
#******************************************CROSS VALIDATION METRIC******************************************




#******************************************CROSS VALIDATION CM******************************************
# Get predictions from cross-validation
y_pred_cv_naiveBayes = cross_val_predict(naiveBayes_classifier, Train_X_normalized, Train_Y, cv=10)

cm = confusion_matrix(Train_Y, y_pred_cv_naiveBayes)

labels = ["Normal", "Pneumonia"]

plt.figure(figsize=(4, 4))  # WIDTH HEIGHT
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False, xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix - Naive Bayes')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.xticks(rotation=90, fontsize=10)  
plt.yticks(rotation=0, fontsize=10)   

plt.tight_layout()

plt.show()
#******************************************CROSS VALIDATION CM******************************************




#******************************************IMAGE VIEWER******************************************
# Misclassified Indices Using Cross-Validation Predictions
misclassified_indices_cv = [i for i, (true, pred) in enumerate(zip(true_labels, y_pred_cv_naiveBayes)) if true != pred]

print("Number of Misclassified Images: ",len(misclassified_indices_cv))

# Display up to 17 misclassified images (or less, if fewer misclassified images)
num_images = min(100, len(misclassified_indices_cv))  # Display up to 17 misclassified images

# Calculate rows and columns for a square grid
grid_size = math.ceil(math.sqrt(num_images))  # Grid size for square layout

plt.figure(figsize=(10, 10))  # Adjust figure size

for idx, mis_idx in enumerate(misclassified_indices_cv[:num_images]):
    # Load image
    img_path = image_paths[mis_idx]
    img = plt.imread(img_path)  # Read the image
    
    # Get true and predicted labels
    true_label = true_labels[mis_idx]
    predicted_label = y_pred_cv_naiveBayes[mis_idx]

    # Modify true_label based on the conditions
    if true_label == "PNEUMONIA":
        true_label = "Pneumonia"
    elif true_label == "NORMAL":
        true_label = "Normal"
    
    # Modify predicted_label based on the conditions
    if predicted_label == "PNEUMONIA":
        predicted_label = "Pneumonia"
    elif predicted_label == "NORMAL":
        predicted_label = "Normal"

    # Plot the image
    plt.subplot(grid_size, grid_size, idx + 1)
    #plt.subplot(1, 5, idx + 1)
    plt.imshow(img, cmap='gray')  # Adjust 'gray' if images are in grayscale
    plt.title(f"True: {true_label}\nPred: {predicted_label}")
    plt.axis("off")

plt.tight_layout()
plt.show()
#******************************************IMAGE VIEWER******************************************
# Out:
# 10 Cross-Validation Results:
# Accuracy Score  : 91.03%
# F1 Score        : 90.95%
# Recall Score    : 91.03%
# Precision Score : 91.86%
# Number of Misclassified Images:  26
